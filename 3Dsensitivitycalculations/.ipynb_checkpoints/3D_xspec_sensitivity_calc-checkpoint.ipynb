# %%
import sys
sys.path.insert(0, '/Users/abrahamn/21cmIR/21cmIRxcor/')
import mwa_utils

# %%
import pickle
import numpy as np
from numpy import pi
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# MWA uv space sampling
analysis_root = '/Volumes/abraham/xcor_data/analysis/21cmfreqavgcubes/'
fhddeeplabel = 'Combined_obs_wedge_cut_plus_res_cut'
mwa_deep_image = pickle.load( open( analysis_root+fhddeeplabel+'.p', "rb" ) )

# %%
# cosmology
from cosmocalc import cosmocalc
WM,WV = 0.27,0.73
c = 3.e8
h = 6.626e-34 # J*sec
c_over_H0_Mpc = 4283.

# rest frame freqs
lamda0_IR_m = 120.e-9
f0_21_Hz = 1420.e6

lamda = 300./185

# %%
# SPHEREx
spherex = {'name':'SPHEREx'}
spherex['Isky_kjy_per_sr'] = 1.e3 # kJy/sr, space
spherex['A_IR'] = 0.2**2  # m^2
spherex['R_IR'] = 40.
spherex['fov_rad'] = 5.*np.pi/180.

# SPHEREx at the north celestial poles, where zod is negligible, and we use the instrumental noise given in Sec. 4.2 of Heneka+ 2016
spherex_ncp = {'name':'SPHEREx-NCP'}
spherex_ncp['A_IR'] = 0.2**2  # m^2
spherex_ncp['R_IR'] = 40.
spherex_ncp['P_IR_shot'] = 3.**2*0.3 # (kJy/sr)^2*Mpc^3

# %%
def crop_to_size(img,n):
    n0 = img.shape[0]
    return img[n0/2-n/2:n0/2+n/2,n0/2-n/2:n0/2+n/2]

# %%
# MWA uv weights
mwa = {'fov_rad': mwa_deep_image.n*mwa_deep_image.dtheta_rad,\
       'dtheta_rad': mwa_deep_image.dtheta_rad}
#mwa['Nperp'] = mwa_deep_image.n
mwa['Nperp'] = int(spherex['fov_rad']/mwa_deep_image.dtheta_rad)
mwa['weights_uv'] = np.abs(np.fft.fft2(crop_to_size(mwa_deep_image.weights_xx0,mwa['Nperp'])))
mwa['Nant'] = 112
mwa['A_21'] = 20.
mwa['half_beam_width_deg'] = lamda/4./2*180/np.pi
mwa['name'] = 'MWA'

# %%
def baselines_uv_to_weights_uv(bl_u,bl_v,Nperp,fov_rad,dtheta_rad):
    n = int(fov_rad/dtheta_rad)
    du = 1./fov_rad
    umax = Nperp/2*du

    weights_uv = np.zeros((Nperp,Nperp))
    for ui in range(Nperp):
        for vi in range(Nperp):
            inpixel = (bl_u > -umax+ui*du)&(bl_u < -umax+(ui+1)*du)&\
                      (bl_v > -umax+vi*du)&(bl_v < -umax+(vi+1)*du)
            weights_uv[ui,vi] += np.sum(inpixel)
            weights_uv[-ui,-vi] += np.sum(inpixel)
    return weights_uv
def ants_to_baselines_uv(ant_x,ant_y):
    num_ants = len(ant_x)
    num_baselines = num_ants*(num_ants-1)/2

    bl_u = np.zeros(num_baselines)
    bl_v = np.zeros(num_baselines)
    k=0
    for i in range(num_ants):
        for j in range(i+1,num_ants):
            bl_u[k] = (ant_x[i]-ant_x[j])/lamda
            bl_v[k] = (ant_y[i]-ant_y[j])/lamda
            k+=1
    return bl_u,bl_v

# %%
# HERA uv weights
fov_deg = 5.
dtheta_amin = 10.

fov_rad = fov_deg*np.pi/180
dtheta_rad = dtheta_amin/60.*np.pi/180.
Nperp = int(fov_rad/dtheta_rad)

hera_arr = np.genfromtxt('/Users/abrahamn/Documents/MIT/21cm/21cmIR/21cmIRxcor/3Dsensitivitycalculations/HERA_Positions_Staged/antenna_positions_350.dat')
Nant = len(hera_arr[:,0])
bl_u,bl_v = ants_to_baselines_uv(hera_arr[:,0],hera_arr[:,1])
weights_uv = baselines_uv_to_weights_uv(bl_u,bl_v,Nperp,fov_rad,dtheta_rad)

hera = {'fov_rad': fov_rad,\
       'dtheta_rad': dtheta_rad,\
       'Nperp': Nperp,\
       'weights_uv': weights_uv,\
       'Nant': Nant,\
       'A_21':100.,\
       'half_beam_width_deg':lamda/14./2*180/np.pi,
       'name':'HERA'}

plt.imshow(weights_uv,interpolation='nearest')

# %%
# SKA uv weights
# aaron says SKA has 497 antennas distributed with gaussian density with std=600m
fov_deg = 5.
dtheta_amin = 2.

fov_rad = fov_deg*np.pi/180
dtheta_rad = dtheta_amin/60.*np.pi/180.
Nperp = int(fov_rad/dtheta_rad)

num_ants = 497
sigma_meters = 600. # see Sec 3.1 of 1610.02689v1
ska_arr = np.random.randn(num_ants,2)*sigma_meters
Nant = len(ska_arr[:,0])
bl_u,bl_v = ants_to_baselines_uv(ska_arr[:,0],ska_arr[:,1])
weights_uv = baselines_uv_to_weights_uv(bl_u,bl_v,Nperp,fov_rad,dtheta_rad)

ska = {'fov_rad': fov_rad,\
       'dtheta_rad': dtheta_rad,\
       'Nperp': Nperp,\
       'weights_uv': weights_uv,\
       'Nant': Nant,\
       'A_21':30.**2,\
       'half_beam_width_deg':lamda/30./2*180/np.pi,
      'name':'SKA1'}

plt.imshow(weights_uv,interpolation='nearest')

# %%
del fov_deg,dtheta_amin,fov_rad,dtheta_rad,Nperp,num_ants,weights_uv

# %%
# 21cm thermal noise
# https://www.evernote.com/shard/s316/nl/2147483647/6f7c9ac4-f872-407d-89e3-acb8fdff1982/

def calc_P_21_thermal_veck(expt,t_int_hours,D,DeltaD,B_21_Hz,Nf,z):
    num_baselines = expt['Nant']*(Nant-1)/2
    num_seconds_per_uv = expt['weights_uv']/np.sum(expt['weights_uv'])*np.sum(num_baselines*t_int_hours*3600)
    
    Tsky_K = 200.
    lamda = .21*(1+z)
    P_21_thermal = (Tsky_K**2)*(lamda**2)*(D**2)*DeltaD/(B_21_Hz*expt['A_21'])/num_seconds_per_uv
    
    return np.repeat([P_21_thermal],Nf,axis=0)

# %%
# IR shot noise
# https://www.evernote.com/shard/s316/nl/2147483647/89eb8fb1-82bf-46c2-a07a-4c81d1fd171b/
# https://www.evernote.com/shard/s316/nl/2147483647/0b490f35-5419-452a-9350-371cc062850b/

def calc_P_IR_shot_veck(expt,t_int_ir_hours,D,DeltaD,B_IR_Hz,Nf,z,Nperp):
    if 'P_IR_shot' in expt.keys():
        P_IR_shot = expt['P_IR_shot']
    else:
        kjy = 1000 * 1.e-26
        hf = h*c/(lamda0_IR_m*(1+z))
        P_IR_shot = D**2*DeltaD*hf*expt['Isky_kjy_per_sr']/(B_IR_Hz*3600*t_int_ir_hours*expt['A_IR']*kjy)

    return np.tile(P_IR_shot,(Nf,Nperp,Nperp))

# %%
def bin_noise_to_1D(P1_veck,P2_veck,nbins,kmin,kmax,kmaggrid,inwindow):
    kbinedges = 10.**np.linspace(np.log10(kmin),np.log10(kmax),nbins+1)
    dk = kbinedges[1]-kbinedges[0]
    kbincenters = .5*(kbinedges[0:nbins]+kbinedges[1:nbins+1])

    P_binned = np.zeros(nbins)
    P_binned_wedgecut = np.zeros(nbins)
    bin_counts = np.zeros(nbins)
    for bini in range(nbins):
        inbin = (kmaggrid>kbinedges[bini])&(kmaggrid<kbinedges[bini+1])
        if inwindow is not None: inbin &= inwindow
            
        if np.sum(inbin)<16: inbin[:] = False
    
        bin_counts[bini] = np.sum(inbin)
        P_binned[bini] = np.sqrt(1./(np.sum( 1./(P1_veck[inbin]*P2_veck[inbin]) )))
        
    return kbinedges,kbincenters,P_binned,bin_counts

# %%
# load Gong theoretical values
gongdat = np.genfromtxt('models/Gong14/gong_lyalpha_model_pspec_upperlimit_z=7.csv',delimiter=',',skip_header=3)
gong_k_upper = gongdat[:,0]
gong_Delta_kjy_per_sr_upperlimit = np.sqrt(gongdat[:,1])*1.e-3  # taking the square root, then multiplying by 1.e-3 
                                                      # converts from (Jy/sr)^2 to (kJy/sr)
gongdat = np.genfromtxt('models/Gong14/gong_lyalpha_model_pspec_lowerlimit_z=7.csv',delimiter=',',skip_header=3)
gong_k_lower = gongdat[:,0]
gong_Delta_kjy_per_sr_lowerlimit = np.sqrt(gongdat[:,1])*1.e-3

# %%
# load vanilla 21cmFAST power spectrum from Pober 14 (what can 21cm observatories teach us about reionization?)
poberdat = np.genfromtxt('models/Pober14/P21_Delta^2_mK^2_late_reionization.csv',delimiter=',',skip_header=3)
pober_k_upperlimit = poberdat[:,0]
pober_Delta_K_upperlimit = np.sqrt(poberdat[:,1])*1.e-3 # taking the square root and multiplying by 1.e-3 
                                                      # converts from mK^2 to K
    
poberdat = np.genfromtxt('models/Pober14/P21_Delta^2_mK^2_fiducial.csv',delimiter=',',skip_header=3)
pober_k_lowerlimit = poberdat[:,0]
pober_Delta_K_lowerlimit = np.sqrt(poberdat[:,1])*1.e-3

# %%
# let's interpolate all these models onto the the same k values
model_k = pober_k_lowerlimit
pober_Delta_K_lowerlimit_model_k = pober_Delta_K_lowerlimit

pober_Delta_K_upperlimit_model_k = np.interp(model_k,pober_k_upperlimit,pober_Delta_K_upperlimit)
gong_Delta_kjy_per_sr_upperlimit_model_k = np.interp(model_k,gong_k_upper,gong_Delta_kjy_per_sr_upperlimit)
gong_Delta_kjy_per_sr_lowerlimit_model_k = np.interp(model_k,gong_k_lower,gong_Delta_kjy_per_sr_lowerlimit)

# %%
def loglogbar(binedges,binyvals,bin_counts,col='k',sty='-',label='',lw=1):
    binedges[binedges==0] = 1.e-6
    binyvals[np.isinf(binyvals)] = 1.e-10
    
    #plt.loglog([binedges[0],binedges[0]],[1.e-6,binyvals[0]],sty,color=col,label=label,linewidth=lw)
    for bini in range(len(binyvals)):
        nextbinval = binyvals[bini+1] if bini+1 < len(binyvals) else 1.e-10
        plt.loglog([binedges[bini],binedges[bini+1],binedges[bini+1]],[binyvals[bini],binyvals[bini],nextbinval],sty,color=col,linewidth=lw)

# %%
def make_legend(labels,cols,stys,lws):
    for i in range(len(labels)):
        plt.loglog(1.e-9,1.e-9,stys[i],color=cols[i],linewidth=lws[i],label=labels[i])
    plt.legend(loc=4,fontsize=10)

def p2(nrows,ncols,currplotindex,expt_ir,expt_21,Deltaz,t_int_mwa_hours,t_int_ir_hours,wedgestyle,wedgestylefov,xlimits,hidexlabels=False,showlegend=False):
    # cosmology
    z = 7.
    Ez = np.sqrt(WM*(1+z)**3+WV)
    D = cosmocalc(z,WM=WM,WV=WV)['DCMR_Mpc']
    DeltaD = c_over_H0_Mpc*Deltaz/Ez
    #wedgeslope_horizon = D*Ez/(c_over_H0_Mpc*(1+z))*(pi/2)
    wedgeslope_horizon = D*Ez/(c_over_H0_Mpc*(1+z))*3*expt_21['half_beam_width_deg']*np.pi/180.
    wedgeslope_fov = D*Ez/(c_over_H0_Mpc*(1+z))*expt_21['half_beam_width_deg']*np.pi/180.
    
    # frequencies and redshifts
    dz = (1+z)/expt_ir['R_IR']
    Nf = int(np.round(Deltaz / dz))
    B_IR_Hz = Deltaz*c/lamda0_IR_m/(1+z)**2
    B_21_Hz = Deltaz*f0_21_Hz/(1+z)**2
    
    # survey geometry
    dkpara = 2.*pi/DeltaD
    kparamax = float(Nf)/2*dkpara
    dkperp = 2.*pi/(expt_21['fov_rad']*D)
    kperpmax = expt_21['Nperp']/2*dkperp
    kparavals = np.fft.fftfreq(Nf)*Nf*dkpara
    kperpvals = np.fft.fftfreq(expt_21['Nperp'])*expt_21['Nperp']*dkperp
    kzgrid,kxgrid,kygrid = np.meshgrid(kparavals,kperpvals,kperpvals,indexing='ij')
    kperpgrid = np.sqrt(kxgrid**2+kygrid**2)
    kmaggrid = np.sqrt(kxgrid**2+kygrid**2+kzgrid**2)
    inwindow_horizon = kzgrid > wedgeslope_horizon*kperpgrid
    inwindow_fov = kzgrid > wedgeslope_fov*kperpgrid
    
    print(expt_ir['name']+'/'+expt_21['name']+':')
    print(np.sum(kzgrid!=-99999999.),np.sum(inwindow_fov),np.sum(inwindow_horizon))

    # calculate thermal and shot noise 3D power spectra (over \vec{k} cube)
    P_21_thermal_veck = calc_P_21_thermal_veck(expt_21,t_int_mwa_hours,D,DeltaD,B_21_Hz,Nf,z)
    print(P_21_thermal_veck.shape)
    P_IR_shot_veck = calc_P_IR_shot_veck(expt_ir,t_int_ir_hours,D,DeltaD,B_IR_Hz,Nf,z,expt_21['Nperp'])
    
    # cross and auto spectra
    nbins = 5
    kmin,kmax = 1.e-2,1
    
    kbinedges,kbincenters,P_binned,bin_counts = bin_noise_to_1D(P_IR_shot_veck,P_21_thermal_veck,nbins,kmin,kmax,kmaggrid,inwindow=None)
    kbinedges,kbincenters,P_binned_wedgecut,bin_counts_wedgecut = bin_noise_to_1D(P_IR_shot_veck,P_21_thermal_veck,nbins,kmin,kmax,kmaggrid,inwindow_horizon)
    kbinedges,kbincenters,P_binned_wedgecutfov,bin_counts_wedgecut = bin_noise_to_1D(P_IR_shot_veck,P_21_thermal_veck,nbins,kmin,kmax,kmaggrid,inwindow_fov)
      
    kbinedges,kbincenters,P_21_binned,bin_counts = bin_noise_to_1D(P_21_thermal_veck,P_21_thermal_veck,nbins,kmin,kmax,kmaggrid,inwindow=None)
    kbinedges,kbincenters,P_21_binned_wedgecut,bin_counts = bin_noise_to_1D(P_21_thermal_veck,P_21_thermal_veck,nbins,kmin,kmax,kmaggrid,inwindow_horizon)
    kbinedges,kbincenters,P_21_binned_wedgecutfov,bin_counts = bin_noise_to_1D(P_21_thermal_veck,P_21_thermal_veck,nbins,kmin,kmax,kmaggrid,inwindow_fov)
    
    kbinedges,kbincenters,P_IR_binned,bin_counts = bin_noise_to_1D(P_IR_shot_veck,P_IR_shot_veck,nbins,kmin,kmax,kmaggrid,inwindow=None)
    kbinedges,kbincenters,P_IR_binned_wedgecut,bin_counts = bin_noise_to_1D(P_IR_shot_veck,P_IR_shot_veck,nbins,kmin,kmax,kmaggrid,inwindow_horizon)
    kbinedges,kbincenters,P_IR_binned_wedgecutfov,bin_counts = bin_noise_to_1D(P_IR_shot_veck,P_IR_shot_veck,nbins,kmin,kmax,kmaggrid,inwindow_fov)


    plt.subplot(nrows,ncols,currplotindex)
    
    if showlegend: make_legend(labels=['all bins','3xFOV wedge','FOV wedge'],cols=['k','r','b'],stys=['-',wedgestyle,wedgestylefov],lws=[1,3,3])
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_binned,bin_counts,col='k',lw=1)
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_binned_wedgecut,bin_counts,col='r',sty=wedgestyle,lw=3)
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_binned_wedgecutfov,bin_counts,col='b',sty=wedgestylefov,lw=3)
    plt.fill_between(model_k,pober_Delta_K_lowerlimit_model_k*gong_Delta_kjy_per_sr_lowerlimit_model_k,\
               pober_Delta_K_upperlimit_model_k*gong_Delta_kjy_per_sr_upperlimit_model_k,color='k',alpha=.05)
    if not hidexlabels: plt.xlabel('k (1/Mpc)')
    plt.ylabel(r'$\Delta^2_{21,IR}$ (K$\cdot$kJy/sr)')
    plt.xlim(xlimits)
    plt.ylim([7.e-8,1.e-3])
    plt.text(.015,.5*1.e-3,expt_ir['name']+'/'+expt_21['name'],va='top')
    

    plt.subplot(nrows,ncols,currplotindex+1)
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_21_binned,bin_counts,col='k',lw=1)
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_21_binned_wedgecut,bin_counts,col='r',sty=wedgestyle,lw=3)
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_21_binned_wedgecutfov,bin_counts,col='b',sty=wedgestylefov,lw=3)
    plt.fill_between(model_k, pober_Delta_K_lowerlimit_model_k**2, pober_Delta_K_upperlimit_model_k**2,alpha=.05,color='k')
    if not hidexlabels: plt.xlabel('k (1/Mpc)')
    plt.ylabel(r'$\Delta^2_{21}$ (K$^2$)')
    plt.gca().yaxis.set_ticklabels([])
    plt.text(.015,.5*1.e-3,expt_21['name'],va='top')
    plt.xlim(xlimits)
    plt.ylim([.1e-8,1.e-3])

    plt.subplot(nrows,ncols,currplotindex+2)
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_IR_binned,bin_counts,col='k',lw=1)
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_IR_binned_wedgecut,bin_counts,col='r',sty=wedgestyle,lw=3)
    loglogbar(kbinedges,kbincenters**3/(2*pi**2)*P_IR_binned_wedgecutfov,bin_counts,col='b',sty=wedgestylefov,lw=3)
    plt.fill_between(model_k,gong_Delta_kjy_per_sr_lowerlimit_model_k**2,gong_Delta_kjy_per_sr_upperlimit_model_k**2,alpha=.05,color='k')
    plt.text(.015,.5*1.5e-2,expt_ir['name'],va='top')
    if not hidexlabels: plt.xlabel('k (1/Mpc)')
    plt.ylabel(r'$\Delta^2_{IR}$ (kJy/sr)$^2$')
    plt.gca().yaxis.set_ticklabels([])
    plt.xlim(xlimits)
    plt.ylim([1.e-7,1.5e-2])
    
    currplotindex += 3

# %%
matplotlib.rcParams.update({'font.size': 14})
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
plt.figure(figsize=(12,15))

nrows,ncols = 4,3
wedgestyle = '--'
wedgestylefov = ':'
xlimits = [1.e-2,1]

t_int_mwa_hours = 100.
t_int_ir_hours = 1.

p2(nrows,ncols,1,spherex,mwa,1.6, t_int_mwa_hours, t_int_ir_hours,wedgestyle,wedgestylefov,xlimits,hidexlabels=True,showlegend=True)
p2(nrows,ncols,4,spherex,hera,1.6, t_int_mwa_hours, t_int_ir_hours,wedgestyle,wedgestylefov,xlimits,hidexlabels=True)
p2(nrows,ncols,7,spherex,ska,1.6, t_int_mwa_hours, t_int_ir_hours,wedgestyle,wedgestylefov,xlimits,hidexlabels=True)
p2(nrows,ncols,10,spherex_ncp,ska,1.6, t_int_mwa_hours, t_int_ir_hours,wedgestyle,wedgestylefov,xlimits)

plt.tight_layout()
plt.savefig('cross_and_auto_sensitivity_for_diff_expts.pdf',bbox_inches='tight')
# Out:
# SPHEREx/MWA:
# (14112, 1115, 127)
# (8, 42, 42)
# /Users/abrahamn/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:16: RuntimeWarning: divide by zero encountered in double_scalars
# SPHEREx/HERA:
# (7200, 1788, 279)
# (8, 30, 30)
# SPHEREx/SKA1:
# (180000, 11495, 1267)
# (8, 150, 150)
# /Users/abrahamn/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:10: RuntimeWarning: divide by zero encountered in divide
# SPHEREx-NCP/SKA1:
# (180000, 11495, 1267)
# (8, 150, 150)
