# %%
import numpy as np

import sys # needed to import cat_utils
sys.path.insert(0, '/Users/abrahamn/21cmIR/21cmIRxcor/')

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

import imp
import cat_utils
imp.reload(cat_utils)

import cPickle as pickle

from astropy.io import fits

# %%
# load IR catalogs
wisecats = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/wisecats.p",'rb'))

w1scos = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w1scos.p",'rb'))
w2scos = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w2scos.p",'rb'))

secat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/whole_field_secat.p', "rb" ) )

# %%
# load MWA catalog

hdulist = fits.open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/carroll16/KGS.fits')
g = hdulist[1].data['R_class'] <= 6
carroll16cat = cat_utils.Catalog(hdulist[1].data['RAJ2000'][g],\
                                 hdulist[1].data['DECJ2000'][g],\
                                 hdulist[1].data['S_182'][g],\
                                 hdulist[1].data['e_RAJ2000'][g],\
                                 hdulist[1].data['e_DECJ2000'][g])

# %%
dtheta_deg = 2./60

# %%
# generate images

boundcat = wisecats[0]

# mwa_img,mwa_img_counts = cat_utils.cat2img(carroll16cat.with_flux_cuts(0,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
# pickle.dump([mwa_img,mwa_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/mwa_img_with_counts.p", "wb" ) )

# w2scos_img,w2scos_img_counts = cat_utils.cat2img(w2scos.with_flux_cuts(0,90),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
# pickle.dump([w2scos_img,w2scos_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2scos_img_with_counts.p", "wb" ) )

# w2_img,w2_img_counts = cat_utils.cat2img(wisecats[1].with_flux_cuts(0,90),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
# pickle.dump([w2_img,w2_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_img_with_counts.p", "wb" ) )

# w3_img,w3_img_counts = cat_utils.cat2img(wisecats[3].with_flux_cuts(0,90),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
# pickle.dump([w3_img,w4_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w4_img_with_counts.p", "wb" ) )

# w4_img,w4_img_counts = cat_utils.cat2img(wisecats[3].with_flux_cuts(0,90),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
# pickle.dump([w4_img,w4_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w4_img_with_counts.p", "wb" ) )

# %%
wiseagncat = pickle.load( open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/wiseagncat_eor0.p", "rb" ) )
wiseagncat_img,wiseagncat_img_counts = cat_utils.cat2img(wiseagncat.with_flux_cuts(0,90),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([wiseagncat_img,wiseagncat_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/wiseagncat_eor0_img_with_counts.p", "wb" ) )
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
secat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/whole_field_secat.p', "rb" ) )
secat_img,secat_img_counts = cat_utils.cat2img(secat.with_flux_cuts(0,90),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([secat_img,secat_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/secat_img_with_counts.p", "wb" ) )
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
# load pickeled images

mwa_img,mwa_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/mwa_img_with_counts.p",'rb'))
secat_img,secat_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/secat_img_with_counts.p",'rb'))
w2scos_img,w2scos_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2scos_img_with_counts.p",'rb'))
w2_img,w2_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_img_with_counts.p",'rb'))
wiseagncat_img,wiseagncat_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/wiseagncat_eor0_img_with_counts.p",'rb'))

# %%
# catalogs to coherence (ie, normalized cross spectrum)
def imgs_to_cspec(img1,img2,dtheta_deg,nbins,lmin,lmax,label,hann=True,ylim=[-.2,.2],xlim=[1,300]):
    lbins,pspec1,pspec2,xspec,bin_counts = cat_utils.calc_xspec(img1,img2,dtheta_deg,nbins=nbins,lmin=lmin,lmax=lmax,hann=hann,uselogbins=True)
    lbins,pspec1_f,pspec2_f,xspec_f,bin_counts = cat_utils.calc_xspec(img1,np.rot90(img2),dtheta_deg,nbins=nbins,lmin=lmin,lmax=lmax,hann=hann,uselogbins=True)

    c = xspec/np.sqrt(pspec1*pspec2)
    dc = np.sqrt(.5*(1+c**2)/(1.*bin_counts/4))

    c_f = xspec_f/np.sqrt(pspec1_f*pspec2_f)
    dc_f = np.sqrt(.5*(1+c_f**2)/(1.*bin_counts/4))

    plt.figure(figsize=(34,4))
    plt.subplot(161)
    plt.imshow(img1)
    plt.colorbar()
    
    plt.subplot(162)
    plt.imshow(img2)
    plt.colorbar()

    plt.subplot(163)
    thetabins = 180.*60/lbins
    plt.loglog(thetabins,pspec1,'b.-')
    plt.loglog(thetabins*1.1,pspec1_f,'r.-')
    plt.xlim(xlim)
    plt.xlabel('180*60/ell (amin)')
    plt.title('pspec1')
    
    plt.subplot(164)
    thetabins = 180.*60/lbins
    plt.loglog(thetabins,pspec2,'b.-')
    plt.loglog(thetabins*1.1,pspec2,'r.-')
    plt.xlim(xlim)
    plt.xlabel('180*60/ell (amin)')
    plt.title('pspec2')
    
    plt.subplot(165)
    thetabins = 180.*60/lbins
    plt.loglog(thetabins,xspec,'b.-')
    plt.loglog(thetabins*1.1,xspec_f,'r.-')
    plt.semilogx([.1,1000],[0,0],'k-')
    plt.xlim(xlim)
    plt.xlabel('180*60/ell (amin)')
    plt.title('xspec')
    
    plt.subplot(166)
    thetabins = 180.*60/lbins
    plt.errorbar(thetabins,c,yerr=dc,fmt='b.-')
    plt.errorbar(thetabins*1.1,c_f,yerr=dc_f,fmt='r.-')
    plt.semilogx([.1,1000],[0,0],'k-')
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.xlabel('180*60/ell (amin)')
    plt.title(label)
    print(c)
    print(bin_counts)
nbins=10
lmin,lmax = 10,7500

# catalogs to coherence (ie, normalized cross spectrum)
def imgs_to_cspec_ell(img1,img2,dtheta_deg,nbins,lmin,lmax,label,hann=True,ylim=[-.2,.2],xlim=[1,300]):
    lbins,pspec1,pspec2,xspec,bin_counts = cat_utils.calc_xspec(img1,img2,dtheta_deg,nbins=nbins,lmin=lmin,lmax=lmax,hann=hann,uselogbins=False)
    lbins,pspec1_f,pspec2_f,xspec_f,bin_counts = cat_utils.calc_xspec(img1,np.rot90(img2),dtheta_deg,nbins=nbins,lmin=lmin,lmax=lmax,hann=hann,uselogbins=False)

    c = xspec/np.sqrt(pspec1*pspec2)
    dc = np.sqrt(.5*(1+c**2)/(1.*bin_counts/4))

    c_f = xspec_f/np.sqrt(pspec1_f*pspec2_f)
    dc_f = np.sqrt(.5*(1+c_f**2)/(1.*bin_counts/4))

    plt.figure(figsize=(34,4))
    plt.subplot(161)
    plt.imshow(img1)
    plt.colorbar()
    
    plt.subplot(162)
    plt.imshow(img2)
    plt.colorbar()

    plt.subplot(163)
    thetabins = 180.*60/lbins
    plt.plot(lbins,np.sqrt(lbins*(lbins+1)*pspec1/(2*np.pi)),'b.-')
    plt.plot(lbins*1.1,np.sqrt(lbins*(lbins+1)*pspec1_f/(2*np.pi)),'r.-')
    plt.xlim(xlim)
    plt.xlabel('180*60/ell (amin)')
    plt.title('pspec1')
    
    plt.subplot(164)
    thetabins = 180.*60/lbins
    plt.plot(lbins,np.sqrt(lbins*(lbins+1)*pspec2/(2*np.pi)),'b.-')
    plt.plot(lbins*1.1,np.sqrt(lbins*(lbins+1)*pspec2/(2*np.pi)),'r.-')
    plt.xlim(xlim)
    plt.ylim([0,0.0002])
    plt.xlabel('180*60/ell (amin)')
    plt.title('pspec2')
    
    plt.subplot(165)
    thetabins = 180.*60/lbins
    plt.plot(lbins,xspec,'b.-')
    plt.plot(lbins*1.1,xspec_f,'r.-')
    plt.semilogx([.1,1000],[0,0],'k-')
    plt.xlim(xlim)
    plt.xlabel('180*60/ell (amin)')
    plt.title('xspec')
    
    plt.subplot(166)
    thetabins = 180.*60/lbins
    plt.errorbar(lbins,c,yerr=dc,fmt='b.-')
    plt.errorbar(lbins*1.1,c_f,yerr=dc_f,fmt='r.-')
    plt.semilogx([.1,1000],[0,0],'k-')
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.xlabel('180*60/ell (amin)')
    plt.title(label)
    print(c)
    print(bin_counts)
nbins=10
lmin,lmax = 10,7500

# %%
imgs_to_cspec(mwa_img,w2scos_img,dtheta_deg,nbins,lmin,lmax,'w2 scos '+str(np.sum(w2scos_img_counts)))
# Out:
# maximum ell is 7622
# maximum ell is 7622
# [        nan         nan  0.77885554 -0.4089587  -0.26212833 -0.1628973
#   0.19495408  0.23931299  0.14556216  0.00825676  0.06209623  0.01275551
#   0.08005678 -0.00440997  0.03268699  0.02659559  0.02263811 -0.00091434
#   0.00390295 -0.01142367]
# [  0.00000000e+00   0.00000000e+00   4.00000000e+00   4.00000000e+00
#    1.20000000e+01   2.40000000e+01   3.60000000e+01   6.40000000e+01
#    1.48000000e+02   2.84000000e+02   5.40000000e+02   1.06000000e+03
#    2.02800000e+03   3.93200000e+03   7.67200000e+03   1.48760000e+04
#    2.88280000e+04   5.58720000e+04   1.08272000e+05   6.23880000e+04]

# %%
imgs_to_cspec(mwa_img,w2_img,dtheta_deg,nbins,lmin,lmax)
# Out:
# maximum ell is 7622
# maximum ell is 7622

# %%
imgs_to_cspec(mwa_img,w4_img,dtheta_deg,nbins,lmin,lmax)
# Out:
# maximum ell is 7622
# maximum ell is 7622

# %%
imgs_to_cspec(mwa_img_counts,w4_img_counts,dtheta_deg,nbins,lmin,lmax)
# Out:
# maximum ell is 7622
# maximum ell is 7622

# %%
imgs_to_cspec(mwa_img,wiseagncat_img,dtheta_deg,nbins,lmin,lmax,'wise agn '+str(np.sum(wiseagncat_img)))
# Out:
# maximum ell is 7622
# maximum ell is 7622
# [             nan              nan   7.43991289e-02  -8.40715691e-01
#   -2.79417306e-01   4.17763522e-01   4.27814175e-01  -1.65464821e-01
#    1.61021356e-05  -1.94076372e-01  -1.05831685e-01  -1.00509138e-02
#    2.76853612e-02   5.87907110e-02   7.48193446e-03  -8.69700976e-03
#   -1.37568637e-02   1.13067478e-03   8.01617260e-03   9.24791939e-04]
# [  0.00000000e+00   0.00000000e+00   4.00000000e+00   4.00000000e+00
#    1.20000000e+01   2.40000000e+01   3.60000000e+01   6.40000000e+01
#    1.48000000e+02   2.84000000e+02   5.40000000e+02   1.06000000e+03
#    2.02800000e+03   3.93200000e+03   7.67200000e+03   1.48760000e+04
#    2.88280000e+04   5.58720000e+04   1.08272000e+05   6.23880000e+04]

# %%
imgs_to_cspec(mwa_img,secat_img,dtheta_deg,nbins,lmin,lmax)
# Out:
# maximum ell is 7622
# maximum ell is 7622

# %%
w2_qso_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w2_qso.p', "rb" ) )
w2_qso_img,w2_qso_img_counts = cat_utils.cat2img(w2_qso_cat.with_flux_cuts(0,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([w2_qso_img,w2_qso_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_qso_img_with_counts.p", "wb" ) )

w2_agn_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w2_agn.p', "rb" ) )
w2_agn_img,w2_agn_img_counts = cat_utils.cat2img(w2_agn_cat.with_flux_cuts(0,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([w2_agn_img,w2_agn_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_agn_img_with_counts.p", "wb" ) )

w2_sf_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w2_sf.p', "rb" ) )
w2_sf_img,w2_sf_img_counts = cat_utils.cat2img(w2_sf_cat.with_flux_cuts(0,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([w2_sf_img,w2_sf_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_sf_img_with_counts.p", "wb" ) )
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
w3_qso_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w3_qso.p', "rb" ) )
w3_qso_img,w3_qso_img_counts = cat_utils.cat2img(w3_qso_cat.with_flux_cuts(0,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([w3_qso_img,w3_qso_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w3_qso_img_with_counts.p", "wb" ) )

w3_agn_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w3_agn.p', "rb" ) )
w3_agn_img,w3_agn_img_counts = cat_utils.cat2img(w3_agn_cat.with_flux_cuts(0,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([w3_agn_img,w3_agn_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w3_agn_img_with_counts.p", "wb" ) )

w3_sf_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w3_sf.p', "rb" ) )
w3_sf_img,w3_sf_img_counts = cat_utils.cat2img(w3_sf_cat.with_flux_cuts(0,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([w3_sf_img,w3_sf_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w3_sf_img_with_counts.p", "wb" ) )
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
w3_qso_img,w3_qso_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w3_qso_img_with_counts.p", "rb" ) )
w3_agn_img,w3_agn_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w3_agn_img_with_counts.p", "rb" ) )
w3_sf_img,w3_sf_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w3_sf_img_with_counts.p", "rb" ) )

# %%
imgs_to_cspec(mwa_img,w3_qso_img,dtheta_deg,nbins,lmin,lmax,label='MWA/w2_qso '+str(np.sum(w3_qso_img_counts)))
imgs_to_cspec(mwa_img,w3_agn_img,dtheta_deg,nbins,lmin,lmax,label='MWA/w2_agn '+str(np.sum(w3_agn_img_counts)))
imgs_to_cspec(mwa_img,w3_sf_img,dtheta_deg,nbins,lmin,lmax,label='MWA/w2_sf '+str(np.sum(w3_sf_img_counts)))
# Out:
# maximum ell is 7622
# maximum ell is 7622
# [        nan         nan -0.66539051 -0.75865332  0.02051669  0.54917086
#   0.01286395  0.1700949   0.0458758  -0.0825635   0.02736905  0.0081749
#   0.06788357  0.028222    0.00432686  0.01134519  0.01743207  0.01067696
#   0.01055503  0.00906969]
# [  0.00000000e+00   0.00000000e+00   4.00000000e+00   4.00000000e+00
#    1.20000000e+01   2.40000000e+01   3.60000000e+01   6.40000000e+01
#    1.48000000e+02   2.84000000e+02   5.40000000e+02   1.06000000e+03
#    2.02800000e+03   3.93200000e+03   7.67200000e+03   1.48760000e+04
#    2.88280000e+04   5.58720000e+04   1.08272000e+05   6.23880000e+04]
# maximum ell is 7622
# maximum ell is 7622
# [        nan         nan  0.57321861 -0.39347593 -0.00676854  0.26794274
#   0.47624878  0.22398782  0.12721385  0.10024454  0.02268392 -0.00664391
#   0.04086274  0.00107221 -0.02718297  0.0310114  -0.00879573  0.00443064
#  -0.00256297  0.00233183]
# ...

# %%
w2_g1g2g3_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w2_g1g2g3.p', "rb" ) )
w2_g1g2g3_img,w2_g1g2g3_img_counts = cat_utils.cat2img(w3_qso_cat.with_flux_cuts(0,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
pickle.dump([w2_g1g2g3_img,w2_g1g2g3_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_g1g2g3_img_with_counts.p", "wb" ) )
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
imgs_to_cspec(mwa_img,w2_img,dtheta_deg,nbins,lmin,lmax,label='MWA/w3_agn')
imgs_to_cspec(mwa_img,w2_g1g2g3_img,dtheta_deg,nbins,lmin,lmax,label='MWA/w2_g1g2g3') # clearly by requiring a W3 detection, we are filtering out important stuff
# Out:
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622

# %%
w2_qsoagn_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w2_w1-w2>0.6.p', "rb" ) )
w2_qsoagn_img,w2_qsoagn_img_counts = cat_utils.cat2img(w2_qsoagn_cat,bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True,jymax=np.percentile(wisecats[1].jy,90))
pickle.dump([w2_qsoagn_img,w2_qsoagn_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_w1-w2>0.6_img_with_counts.p", "wb" ) )

w2_qsoagn2_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w2_w1-w2<0.6.p', "rb" ) )
w2_qsoagn2_img,w2_qsoagn2_img_counts = cat_utils.cat2img(w2_qsoagn2_cat,bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True,jymax=np.percentile(wisecats[1].jy,90))
pickle.dump([w2_qsoagn2_img,w2_qsoagn2_img_counts], open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_w1-w2<0.6_img_with_counts.p", "wb" ) )
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
w2_qsoagn_cat.ra.shape, w2_qsoagn2_cat.ra.shape
# Out:
# ((869556,), (2710412,))

# %%
w2_qsoagn_cat.with_flux_cuts(0,90).ra.shape, w2_qsoagn2_cat.with_flux_cuts(0,90).ra.shape
# Out:
# ((782419,), (2439179,))

# %%
nbins=15
imgs_to_cspec(mwa_img,w2_qsoagn_img,dtheta_deg,nbins,lmin,lmax,label='MWA/(w2 where w1-w2>.6, filtered below 90% of all w2)')
imgs_to_cspec(mwa_img,w2_qsoagn2_img,dtheta_deg,nbins,lmin,lmax,label='MWA/(w2 where w1-w2<.6, filtered below 90% of all w2)')
imgs_to_cspec(mwa_img,w2_qsoagn_img+w2_qsoagn2_img,dtheta_deg,nbins,lmin,lmax,label='MWA/(w2, sum of two prev. , filtered below 90% of all w2)')
imgs_to_cspec(mwa_img,w2_img,dtheta_deg,nbins,lmin,lmax,label='MWA/(w2img, filtered below 90% of all w2)')
# Out:
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622

# %%
is that the hann window I see there? induces correlations on long angular scales? think about it...
# Out:
#   File "<ipython-input-139-f7a83a21f386>", line 1
#     is that the hann window I see there? induces correlations on long angular scales? think about it...
#      ^
# SyntaxError: invalid syntax

# %%
nbins = 60
imgs_to_cspec_ell(mwa_img,w2_img,dtheta_deg,nbins,lmin,lmax,label='MWA/(w2img, filtered below 90% of all w2)',hann=True,ylim=[-.2,1],xlim=[1,1500])
imgs_to_cspec_ell(mwa_img,w2_img,dtheta_deg,nbins,lmin,lmax,label='MWA/(w2img, filtered below 90% of all w2)',hann=False,ylim=[-.2,1],xlim=[1,1500])
# Out:
# maximum ell is 7622
# maximum ell is 7622
# [ 0.44347629  0.2079949   0.15232467  0.02870207  0.07148414  0.05382646
#   0.10327781 -0.00103937  0.03208137  0.02230511  0.0265678   0.04605579
#   0.01394561 -0.01000014 -0.00780136  0.05216382 -0.00208666  0.04160111
#   0.04401451  0.05783622  0.05465589  0.01863368  0.04868503  0.03356261
#   0.03478727 -0.01509276  0.02372231  0.03665621  0.03129164 -0.00688054
#  -0.00662566  0.02495285  0.02014562  0.01405055  0.00108773  0.01473635
#   0.01921338 -0.01807549  0.02162245  0.00748815  0.03688456 -0.00098062
#   0.03390346  0.03402738  0.02043065  0.01068932  0.03849952 -0.00407419
#   0.01846995  0.04471355 -0.03198856 -0.01978201  0.02832448 -0.01056553
#   0.07428503 -0.00957946  0.12647266  0.05309975  0.10312234 -0.03711793]
# [   136.    380.    620.    864.   1124.   1320.   1560.   1812.   2108.
#    2292.   2536.   2776.   3004.   3276.   3520.   3748.   3976.   4204.
# ...

# %%
# compare with SDSS angular power spectrun

lbins,pspec1,pspec2,xspec,bin_counts = cat_utils.calc_xspec(w2_img_counts,w2_img,dtheta_deg,nbins=35,lmin=0,lmax=1500,hann=True,uselogbins=False)

plt.loglog(lbins,pspec1*.05,'r.')
plt.loglog([30,100,300,600],[4.e-5,8.e-6,1.e-6,6.e-7],'k-')
# Out:
# maximum ell is 7622

# %%
w2_qsoagn_cat = pickle.load( open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/w2_w1-w2>0.6.p', "rb" ) )

# %%
w2_qsoagn_cat.with_flux_cuts(70,100).ra.shape
# Out:
# (260825,)

# %%
w2_qsoagn_img_fluxlimit,w2_qsoagn_img_counts = cat_utils.cat2img(w2_qsoagn_cat.with_flux_cuts(70,90),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
w2_qsoagn_img, w2_qsoagn_img_counts = pickle.load(open( "/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mwa_and_ir_catalogs_xcor2/w2_w1-w2>0.6_img_with_counts.p", "rb" ) )

# %%
w2_qsoagn_img_fluxlimit2,w2_qsoagn_img_counts = cat_utils.cat2img(w2_qsoagn_cat.with_flux_cuts(92,95),bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
w = cat_utils.Catalog(w2_qsoagn_cat.ra[0:10000],w2_qsoagn_cat.dec[0:10000],w2_qsoagn_cat.jy[0:10000])
w2_qsoagn_img_fluxlimit3,w2_qsoagn_img_counts = cat_utils.cat2img(w,bound_cat=boundcat,dtheta_deg=dtheta_deg,verbose=True)
# Out:
# 0.0
# 0.00373831775701
# 0.00747663551402
# 0.011214953271
# 0.014953271028
# 0.018691588785
# 0.0224299065421
# 0.0261682242991
# 0.0299065420561
# 0.0336448598131
# 0.0373831775701
# 0.0411214953271
# 0.0448598130841
# 0.0485981308411
# 0.0523364485981
# 0.0560747663551
# 0.0598130841121
# 0.0635514018692
# 0.0672897196262
# 0.0710280373832
# 0.0747663551402
# 0.0785046728972
# 0.0822429906542
# 0.0859813084112
# 0.0897196261682
# 0.0934579439252
# 0.0971962616822
# 0.100934579439
# 0.104672897196
# 0.108411214953
# 0.11214953271
# 0.115887850467
# 0.119626168224
# 0.123364485981
# 0.127102803738
# 0.130841121495
# 0.134579439252
# 0.138317757009
# 0.142056074766
# 0.145794392523
# 0.14953271028
# 0.153271028037
# 0.157009345794
# 0.160747663551
# 0.164485981308
# 0.168224299065
# 0.171962616822
# 0.175700934579
# 0.179439252336
# 0.183177570093
# 0.18691588785
# 0.190654205607
# 0.194392523364
# 0.198130841121
# 0.201869158879
# 0.205607476636
# 0.209345794393
# 0.21308411215
# ...

# %%
nbins,lmin,lmax = 10,10,7500
lbins,pspec1_fluxlimit2,pspec2,xspec,bin_counts = cat_utils.calc_xspec(w2_qsoagn_img_fluxlimit2,w2_qsoagn_img_fluxlimit,dtheta_deg,nbins=nbins,lmin=lmin,lmax=lmax,hann=True,uselogbins=True)
lbins,pspec1_fluxlimit,pspec2,xspec,bin_counts = cat_utils.calc_xspec(w2_qsoagn_img_fluxlimit,w2_qsoagn_img_fluxlimit,dtheta_deg,nbins=nbins,lmin=lmin,lmax=lmax,hann=True,uselogbins=True)
lbins,pspec1,pspec2,xspec,bin_counts = cat_utils.calc_xspec(w2_qsoagn_img,w2_qsoagn_img,dtheta_deg,nbins=nbins,lmin=lmin,lmax=lmax,hann=True,uselogbins=True)

plt.loglog(lbins,pspec1_fluxlimit2,'-',label='w2_qsoagn_fluxlimit2 90-95')
plt.loglog(lbins,pspec1_fluxlimit,'-',label='w2_qsoagn_fluxlimit 70-90')
plt.loglog(lbins,pspec1,'-',label='w2_qsoagn')
plt.legend(fontsize=8)
# Out:
# maximum ell is 7622
# maximum ell is 7622
# maximum ell is 7622
