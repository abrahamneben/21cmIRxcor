# %%
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
numobjects = 1000
Lrad = np.random.rand(numobjects)
Lir = np.random.rand(numobjects)
dist = 1+100*np.random.rand(numobjects)

# %%
plt.plot(Lir,Lrad,'.')

# %%
plt.loglog(Lir/dist**2,Lrad/dist**2,'.')

# %%
are AGNs closer or farther?... what about in this sample?
