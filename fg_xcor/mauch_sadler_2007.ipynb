# %%
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
rawdat = open('/Users/abrahamn/Documents/MIT/21cm/21cmIR/ir_catalogs/mauch_sadler2007/mnras0375-0931-SD1.txt').readlines()
def f(l):
    return [float(l[44:53]),float(l[53:61]),float(l[71:79]),l[98:].strip()]

# %%
dat = np.array([f(l) for l in rawdat[11:]])

# %%
K = np.array(dat[:,0],dtype=float)
z = np.array(dat[:,1],dtype=float)
jy = np.array(dat[:,2],dtype=float)
obj = dat[:,3]

# %%
plt.plot(K,np.log10(jy),'.',alpha=.1)
plt.xlim([12.8,9])
plt.ylim([.3,2.])
# Out:
# (0.3, 2.0)

# %%
plt.plot(K[isagn],np.log10(jy[isagn]),'.',alpha=.1)
plt.xlim([12.8,9])
plt.ylim([.3,1.5])
# Out:
# (0.3, 1.5)

# %%
plt.plot(K[issf],np.log10(jy[issf]),'.',alpha=.1)
plt.xlim([12.8,9])
plt.ylim([.3,1.5])
# Out:
# (0.3, 1.5)

# %%
np.unique(obj)
# Out:
# array(['?', 'Aa', 'Aa?', 'Aae', 'Aae?', 'Ae', 'Ae?', 'SF', 'SF?', 'star'],
#       dtype='|S32')

# %%
isagn = (obj == 'Aa')|(obj == 'Aae')|(obj == 'Ae')
issf = (obj == 'SF')

# %%
np.sum(isagn)
# Out:
# 2468

# %%
np.sum(issf)
# Out:
# 4421

# %%
plt.hist(z[isagn],50,histtype='step',color='red')
plt.hist(z[issf&(z<.5)],30,histtype='step',color='blue')
plt.legend(['AGN','SF'])

# %%
maybe my correlation is a small, few percent effect that only shows up in intensity mapping...how would it show up here?

# %%
can I try to calculate the correlation coefficient from this sample? even if I can't see anything by eye
there might be a statistically significant detection of a few percent effect...
